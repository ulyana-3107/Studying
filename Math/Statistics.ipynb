# %%
import seaborn as sns
import matplotlib.pyplot as plt

r1 = [2.1711, 1.3523, 1.321, 2.2657, 1.9667, 2.116545, 1.96418, 1.2603, 2.7256, 1.4158]
sns.kdeplot(r1)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# Нормальное распределение

# %%
r2 = [-0.220, -1.2783, 2.67161, 0.16559, 1.60914, 0.03094, -2.371669, -0.289126567, -0.45058537, 2.76730064]
sns.kdeplot(r2)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# Нормальное распределение

# %%
r3 = [-0.98215137, -4.469493, 1.99935121, -0.0141759, 1.3290, -4.501126, 3.5741270, 0.39609510, 0.56368, -1.87383691]
sns.kdeplot(r3)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# Нормальное распределение
